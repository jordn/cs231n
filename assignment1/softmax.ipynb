# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.332437
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** Loss is -log(1/K). Cross entropy loss with even distribution.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.966868 analytic: -0.966868, relative error: 2.935814e-09
# numerical: 1.602633 analytic: 1.602633, relative error: 2.846531e-08
# numerical: -2.209072 analytic: -2.209072, relative error: 2.110137e-09
# numerical: -2.703631 analytic: -2.703631, relative error: 8.337544e-09
# numerical: 2.726025 analytic: 2.726025, relative error: 2.273355e-08
# numerical: 0.785375 analytic: 0.785375, relative error: 4.746656e-10
# numerical: -1.260924 analytic: -1.260923, relative error: 5.463904e-08
# numerical: 1.406322 analytic: 1.406322, relative error: 3.943990e-08
# numerical: 0.951138 analytic: 0.951138, relative error: 3.188025e-08
# numerical: -2.822681 analytic: -2.822681, relative error: 1.418697e-08
# numerical: 1.586939 analytic: 1.586939, relative error: 1.417323e-08
# numerical: 1.383461 analytic: 1.383461, relative error: 3.154649e-08
# numerical: 0.750932 analytic: 0.750932, relative error: 5.955229e-08
# numerical: -3.754644 analytic: -3.754644, relative error: 4.602795e-09
# numerical: 0.780194 analytic: 0.780194, relative error: 3.233800e-08
# numerical: 2.138667 analytic: 2.138667, relative error: 4.451545e-08
# numerical: -4.563524 analytic: -4.563524, relative error: 9.545173e-09
# numerical: -0.634963 analytic: -0.634963, relative error: 1.932509e-08
# numerical: -1.195559 analytic: -1.195559, relative error: 4.023736e-09
# numerical: 2.472293 analytic: 2.472293, relative error: 5.943903e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.332437e+00 computed in 0.088283s
# vectorized loss: 2.332437e+00 computed in 0.004160s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [5e4, 1e8]
learning_rates = np.logspace(-10, -4, 4) # np.logspace(-10, 10, 8) #-10, -9, -8, -7, -6, -5, -4
regularization_strengths = np.logspace(-2, 6, 5) # causes numeric issues: np.logspace(-5, 5, 8) #[-4, -3, -2, -1, 1, 2, 3, 4, 5, 6]
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_accuracy = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_accuracy = np.mean(y_val == y_val_pred)
        print 'LR %f REG %f\n training accuracy: %f, validation accuracy: %f' % (
            lr, reg, train_accuracy, val_accuracy)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax
        results[(lr, reg)] = train_accuracy, val_accuracy
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 1500: loss 5.683681
# iteration 100 / 1500: loss 5.376825
# iteration 200 / 1500: loss 5.885803
# iteration 300 / 1500: loss 5.261513
# iteration 400 / 1500: loss 5.319056
# iteration 500 / 1500: loss 5.213753
# iteration 600 / 1500: loss 5.702800
# iteration 700 / 1500: loss 5.637634
# iteration 800 / 1500: loss 6.265612
# iteration 900 / 1500: loss 5.973509
# iteration 1000 / 1500: loss 5.316078
# iteration 1100 / 1500: loss 5.395349
# iteration 1200 / 1500: loss 5.376956
# iteration 1300 / 1500: loss 5.448779
# iteration 1400 / 1500: loss 5.357786
# LR 0.000000 REG 0.010000 training accuracy: 0.116286
# validation accuracy: 0.121000
# iteration 0 / 1500: loss 5.727862
# iteration 100 / 1500: loss 6.505424
# iteration 200 / 1500: loss 6.221758
# iteration 300 / 1500: loss 6.197550
# iteration 400 / 1500: loss 5.852498
# iteration 500 / 1500: loss 6.277812
# iteration 600 / 1500: loss 6.376889
# iteration 700 / 1500: loss 6.130321
# iteration 800 / 1500: loss 6.330268
# iteration 900 / 1500: loss 5.613610
# iteration 1000 / 1500: loss 6.372098
# iteration 1100 / 1500: loss 6.279714
# iteration 1200 / 1500: loss 6.155595
# iteration 1300 / 1500: loss 6.264864
# iteration 1400 / 1500: loss 5.862359
# LR 0.000000 REG 1.000000 training accuracy: 0.091776
# validation accuracy: 0.093000
# iteration 0 / 1500: loss 6.836898
# iteration 100 / 1500: loss 6.841483
# iteration 200 / 1500: loss 7.314331
# iteration 300 / 1500: loss 7.608196
# iteration 400 / 1500: loss 7.231827
# iteration 500 / 1500: loss 7.128239
# iteration 600 / 1500: loss 7.565163
# iteration 700 / 1500: loss 7.379057
# iteration 800 / 1500: loss 7.712541
# iteration 900 / 1500: loss 7.246606
# iteration 1000 / 1500: loss 7.422730
# iteration 1100 / 1500: loss 7.079648
# iteration 1200 / 1500: loss 7.041288
# iteration 1300 / 1500: loss 7.094791
# iteration 1400 / 1500: loss 7.125784
# LR 0.000000 REG 100.000000 training accuracy: 0.078939
# validation accuracy: 0.077000
# iteration 0 / 1500: loss 159.568177
# iteration 100 / 1500: loss 159.867348
# iteration 200 / 1500: loss 158.785143
# iteration 300 / 1500: loss 159.548624
# iteration 400 / 1500: loss 159.619555
# iteration 500 / 1500: loss 159.384025
# iteration 600 / 1500: loss 159.974330
# iteration 700 / 1500: loss 159.946722
# iteration 800 / 1500: loss 159.554736
# iteration 900 / 1500: loss 159.358368
# iteration 1000 / 1500: loss 159.549305
# iteration 1100 / 1500: loss 158.914478
# iteration 1200 / 1500: loss 158.828163
# iteration 1300 / 1500: loss 159.758355
# iteration 1400 / 1500: loss 159.220736
# LR 0.000000 REG 10000.000000 training accuracy: 0.070000
# validation accuracy: 0.070000
# iteration 0 / 1500: loss 15363.386789
# iteration 100 / 1500: loss 15059.181035
# iteration 200 / 1500: loss 14761.263207
# iteration 300 / 1500: loss 14469.044939
# iteration 400 / 1500: loss 14182.729733
# iteration 500 / 1500: loss 13901.094929
# iteration 600 / 1500: loss 13626.209389
# iteration 700 / 1500: loss 13356.237075
# iteration 800 / 1500: loss 13091.712347
# iteration 900 / 1500: loss 12833.155142
# iteration 1000 / 1500: loss 12578.104275
# iteration 1100 / 1500: loss 12329.082301
# iteration 1200 / 1500: loss 12085.552902
# iteration 1300 / 1500: loss 11846.278276
# iteration 1400 / 1500: loss 11611.143280
# LR 0.000000 REG 1000000.000000 training accuracy: 0.073000
# validation accuracy: 0.086000
# iteration 0 / 1500: loss 6.528314
# iteration 100 / 1500: loss 6.154338
# iteration 200 / 1500: loss 5.720952
# iteration 300 / 1500: loss 5.189940
# iteration 400 / 1500: loss 5.554982
# iteration 500 / 1500: loss 4.866408
# iteration 600 / 1500: loss 4.790613
# iteration 700 / 1500: loss 4.234559
# iteration 800 / 1500: loss 4.230472
# iteration 900 / 1500: loss 4.444608
# iteration 1000 / 1500: loss 4.017492
# iteration 1100 / 1500: loss 4.063934
# iteration 1200 / 1500: loss 4.083121
# iteration 1300 / 1500: loss 3.995491
# iteration 1400 / 1500: loss 3.848618
# LR 0.000000 REG 0.010000 training accuracy: 0.157653
# validation accuracy: 0.164000
# iteration 0 / 1500: loss 5.142145
# iteration 100 / 1500: loss 5.228290
# iteration 200 / 1500: loss 4.689802
# iteration 300 / 1500: loss 4.333996
# iteration 400 / 1500: loss 4.764477
# iteration 500 / 1500: loss 4.160561
# iteration 600 / 1500: loss 3.930983
# iteration 700 / 1500: loss 3.688185
# iteration 800 / 1500: loss 4.083578
# iteration 900 / 1500: loss 3.493638
# iteration 1000 / 1500: loss 3.636890
# iteration 1100 / 1500: loss 3.696790
# iteration 1200 / 1500: loss 3.743508
# iteration 1300 / 1500: loss 3.566899
# iteration 1400 / 1500: loss 3.529221
# LR 0.000000 REG 1.000000 training accuracy: 0.161592
# validation accuracy: 0.165000
# iteration 0 / 1500: loss 6.965308
# iteration 100 / 1500: loss 7.089809
# iteration 200 / 1500: loss 6.446930
# iteration 300 / 1500: loss 6.281861
# iteration 400 / 1500: loss 5.887500
# iteration 500 / 1500: loss 6.149004
# iteration 600 / 1500: loss 5.755234
# iteration 700 / 1500: loss 5.631202
# iteration 800 / 1500: loss 5.526993
# iteration 900 / 1500: loss 5.654921
# iteration 1000 / 1500: loss 5.642973
# iteration 1100 / 1500: loss 5.569603
# iteration 1200 / 1500: loss 5.373381
# iteration 1300 / 1500: loss 5.241004
# iteration 1400 / 1500: loss 5.077520
# LR 0.000000 REG 100.000000 training accuracy: 0.151347
# validation accuracy: 0.156000
# iteration 0 / 1500: loss 157.847980
# iteration 100 / 1500: loss 154.497471
# iteration 200 / 1500: loss 150.900362
# iteration 300 / 1500: loss 148.333352
# iteration 400 / 1500: loss 144.930846
# iteration 500 / 1500: loss 141.718403
# iteration 600 / 1500: loss 138.961582
# iteration 700 / 1500: loss 136.149179
# iteration 800 / 1500: loss 133.178166
# iteration 900 / 1500: loss 130.372962
# iteration 1000 / 1500: loss 127.824103
# iteration 1100 / 1500: loss 125.228553
# iteration 1200 / 1500: loss 123.079711
# iteration 1300 / 1500: loss 120.444240
# iteration 1400 / 1500: loss 117.655967
# LR 0.000000 REG 10000.000000 training accuracy: 0.150102
# validation accuracy: 0.151000
# iteration 0 / 1500: loss 15331.153886
# iteration 100 / 1500: loss 2055.395788
# iteration 200 / 1500: loss 277.144524
# iteration 300 / 1500: loss 39.079759
# iteration 400 / 1500: loss 7.189132
# iteration 500 / 1500: loss 2.925011
# iteration 600 / 1500: loss 2.365357
# iteration 700 / 1500: loss 2.273365
# iteration 800 / 1500: loss 2.270055
# iteration 900 / 1500: loss 2.260030
# iteration 1000 / 1500: loss 2.274650
# iteration 1100 / 1500: loss 2.281944
# iteration 1200 / 1500: loss 2.287868
# iteration 1300 / 1500: loss 2.268459
# iteration 1400 / 1500: loss 2.276217
# LR 0.000000 REG 1000000.000000 training accuracy: 0.256286
# validation accuracy: 0.268000
# iteration 0 / 1500: loss 5.516851
# iteration 100 / 1500: loss 2.749390
# iteration 200 / 1500: loss 2.485475
# iteration 300 / 1500: loss 2.289661
# iteration 400 / 1500: loss 2.166703
# iteration 500 / 1500: loss 2.345104
# iteration 600 / 1500: loss 2.127672
# iteration 700 / 1500: loss 2.190561
# iteration 800 / 1500: loss 2.157157
# iteration 900 / 1500: loss 2.248309
# iteration 1000 / 1500: loss 1.936583
# iteration 1100 / 1500: loss 2.202433
# iteration 1200 / 1500: loss 1.881522
# iteration 1300 / 1500: loss 1.773410
# iteration 1400 / 1500: loss 1.867391
# LR 0.000001 REG 0.010000 training accuracy: 0.344082
# validation accuracy: 0.335000
# iteration 0 / 1500: loss 5.456148
# iteration 100 / 1500: loss 2.690030
# iteration 200 / 1500: loss 2.417539
# iteration 300 / 1500: loss 2.401260
# iteration 400 / 1500: loss 2.234481
# iteration 500 / 1500: loss 2.204342
# iteration 600 / 1500: loss 2.366343
# iteration 700 / 1500: loss 2.347932
# iteration 800 / 1500: loss 2.171842
# iteration 900 / 1500: loss 2.002056
# iteration 1000 / 1500: loss 1.913820
# iteration 1100 / 1500: loss 1.856242
# iteration 1200 / 1500: loss 2.093424
# iteration 1300 / 1500: loss 2.059013
# iteration 1400 / 1500: loss 1.885371
# LR 0.000001 REG 1.000000 training accuracy: 0.348020
# validation accuracy: 0.353000
# iteration 0 / 1500: loss 8.048754
# iteration 100 / 1500: loss 4.540653
# iteration 200 / 1500: loss 3.990164
# iteration 300 / 1500: loss 3.701675
# iteration 400 / 1500: loss 3.719512
# iteration 500 / 1500: loss 3.429844
# iteration 600 / 1500: loss 3.311148
# iteration 700 / 1500: loss 3.147680
# iteration 800 / 1500: loss 3.341500
# iteration 900 / 1500: loss 3.322696
# iteration 1000 / 1500: loss 3.091922
# iteration 1100 / 1500: loss 3.064050
# iteration 1200 / 1500: loss 3.009398
# iteration 1300 / 1500: loss 3.063054
# iteration 1400 / 1500: loss 3.008361
# LR 0.000001 REG 100.000000 training accuracy: 0.353327
# validation accuracy: 0.339000
# iteration 0 / 1500: loss 160.627605
# iteration 100 / 1500: loss 22.364642
# iteration 200 / 1500: loss 4.652052
# iteration 300 / 1500: loss 2.428574
# iteration 400 / 1500: loss 2.020694
# iteration 500 / 1500: loss 1.949579
# iteration 600 / 1500: loss 1.975390
# iteration 700 / 1500: loss 1.915901
# iteration 800 / 1500: loss 1.959350
# iteration 900 / 1500: loss 1.951046
# iteration 1000 / 1500: loss 1.951010
# iteration 1100 / 1500: loss 1.986107
# iteration 1200 / 1500: loss 1.928058
# iteration 1300 / 1500: loss 2.001813
# iteration 1400 / 1500: loss 1.856306
# LR 0.000001 REG 10000.000000 training accuracy: 0.367429
# validation accuracy: 0.378000
# iteration 0 / 1500: loss 15231.229534
# iteration 100 / 1500: loss 2.295900
# iteration 200 / 1500: loss 2.300883
# iteration 300 / 1500: loss 2.298941
# iteration 400 / 1500: loss 2.295953
# iteration 500 / 1500: loss 2.314048
# iteration 600 / 1500: loss 2.307332
# iteration 700 / 1500: loss 2.277036
# iteration 800 / 1500: loss 2.295261
# iteration 900 / 1500: loss 2.289536
# iteration 1000 / 1500: loss 2.314096
# iteration 1100 / 1500: loss 2.304716
# iteration 1200 / 1500: loss 2.321623
# iteration 1300 / 1500: loss 2.293148
# iteration 1400 / 1500: loss 2.296608
# LR 0.000001 REG 1000000.000000 training accuracy: 0.213735
# validation accuracy: 0.209000
# iteration 0 / 1500: loss 5.302839
# iteration 100 / 1500: loss 25.033853
# iteration 200 / 1500: loss 41.193349
# iteration 300 / 1500: loss 31.490017
# iteration 400 / 1500: loss 21.608583
# iteration 500 / 1500: loss 26.475790
# iteration 600 / 1500: loss 19.513186
# iteration 700 / 1500: loss 19.201718
# iteration 800 / 1500: loss 31.024174
# iteration 900 / 1500: loss 20.285952
# iteration 1000 / 1500: loss 21.937451
# iteration 1100 / 1500: loss 27.643226
# iteration 1200 / 1500: loss 18.555560
# iteration 1300 / 1500: loss 35.729602
# iteration 1400 / 1500: loss 21.452741
# LR 0.000100 REG 0.010000 training accuracy: 0.342857
# validation accuracy: 0.331000
# iteration 0 / 1500: loss 5.137840
# iteration 100 / 1500: loss 28.163451
# iteration 200 / 1500: loss 19.177894
# iteration 300 / 1500: loss 32.460271
# iteration 400 / 1500: loss 29.799317
# iteration 500 / 1500: loss 45.716844
# iteration 600 / 1500: loss 27.110592
# iteration 700 / 1500: loss 23.156414
# iteration 800 / 1500: loss 32.100930
# iteration 900 / 1500: loss 28.248502
# iteration 1000 / 1500: loss 38.760111
# iteration 1100 / 1500: loss 29.785531
# iteration 1200 / 1500: loss 30.726280
# iteration 1300 / 1500: loss 23.396195
# iteration 1400 / 1500: loss 46.482188
# LR 0.000100 REG 1.000000 training accuracy: 0.328041
# validation accuracy: 0.300000
# iteration 0 / 1500: loss 6.398483
# iteration 100 / 1500: loss 40.330253
# iteration 200 / 1500: loss 28.216014
# iteration 300 / 1500: loss 34.732051
# iteration 400 / 1500: loss 39.611149
# iteration 500 / 1500: loss 47.467392
# iteration 600 / 1500: loss 35.746907
# iteration 700 / 1500: loss 37.449439
# iteration 800 / 1500: loss 41.907431
# iteration 900 / 1500: loss 53.011889
# iteration 1000 / 1500: loss 30.722992
# iteration 1100 / 1500: loss 27.207826
# iteration 1200 / 1500: loss 18.665517
# iteration 1300 / 1500: loss 27.741840
# iteration 1400 / 1500: loss 35.783709
# LR 0.000100 REG 100.000000 training accuracy: 0.218367
# validation accuracy: 0.215000
# iteration 0 / 1500: loss 161.774689
# iteration 100 / 1500: loss 145.842376
# iteration 200 / 1500: loss 163.219439
# iteration 300 / 1500: loss 183.180419
# iteration 400 / 1500: loss 172.579622
# iteration 500 / 1500: loss 146.365208
# iteration 600 / 1500: loss inf
# iteration 700 / 1500: loss 161.197018
# iteration 800 / 1500: loss inf
# iteration 900 / 1500: loss 154.693184
# iteration 1000 / 1500: loss inf
# iteration 1100 / 1500: loss inf
# iteration 1200 / 1500: loss 151.954108
# iteration 1300 / 1500: loss 176.952481
# iteration 1400 / 1500: loss inf
# LR 0.000100 REG 10000.000000 training accuracy: 0.107204
# validation accuracy: 0.088000
# iteration 0 / 1500: loss 15303.764667
# iteration 100 / 1500: loss nan
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# LR 0.000100 REG 1000000.000000 training accuracy: 0.100265
# validation accuracy: 0.087000
# lr 1.000000e-10 reg 1.000000e-02 train accuracy: 0.116286 val accuracy: 0.121000
# lr 1.000000e-10 reg 1.000000e+00 train accuracy: 0.091776 val accuracy: 0.093000
# lr 1.000000e-10 reg 1.000000e+02 train accuracy: 0.078939 val accuracy: 0.077000
# lr 1.000000e-10 reg 1.000000e+04 train accuracy: 0.070000 val accuracy: 0.070000
# lr 1.000000e-10 reg 1.000000e+06 train accuracy: 0.073000 val accuracy: 0.086000
# lr 1.000000e-08 reg 1.000000e-02 train accuracy: 0.157653 val accuracy: 0.164000
# lr 1.000000e-08 reg 1.000000e+00 train accuracy: 0.161592 val accuracy: 0.165000
# lr 1.000000e-08 reg 1.000000e+02 train accuracy: 0.151347 val accuracy: 0.156000
# lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.150102 val accuracy: 0.151000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.256286 val accuracy: 0.268000
# lr 1.000000e-06 reg 1.000000e-02 train accuracy: 0.344082 val accuracy: 0.335000
# lr 1.000000e-06 reg 1.000000e+00 train accuracy: 0.348020 val accuracy: 0.353000
# lr 1.000000e-06 reg 1.000000e+02 train accuracy: 0.353327 val accuracy: 0.339000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.367429 val accuracy: 0.378000
# lr 1.000000e-06 reg 1.000000e+06 train accuracy: 0.213735 val accuracy: 0.209000
# lr 1.000000e-04 reg 1.000000e-02 train accuracy: 0.342857 val accuracy: 0.331000
# lr 1.000000e-04 reg 1.000000e+00 train accuracy: 0.328041 val accuracy: 0.300000
# lr 1.000000e-04 reg 1.000000e+02 train accuracy: 0.218367 val accuracy: 0.215000
# lr 1.000000e-04 reg 1.000000e+04 train accuracy: 0.107204 val accuracy: 0.088000
# lr 1.000000e-04 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.378000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.366000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
